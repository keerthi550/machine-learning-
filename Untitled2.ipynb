# %% [markdown]
# # CNN Feature Map Visualisation using Fashion-MNIST

# %% [markdown]
# Import the necessary libraries

# %%
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf

from tensorflow.keras.datasets import fashion_mnist
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout
from tensorflow.keras.utils import to_categorical
from sklearn.metrics import confusion_matrix, classification_report

import seaborn as sns
import os

np.random.seed(42)
tf.random.set_seed(42)

# %% [markdown]
# Load the Fashion-MNIST Dataset

# %%
(X_train, y_train), (X_test, y_test) = fashion_mnist.load_data()

class_names = [
    "T-shirt/top", "Trouser", "Pullover", "Dress", "Coat",
    "Sandal", "Shirt", "Sneaker", "Bag", "Ankle boot"
]

print("Training images:", X_train.shape)
print("Testing images:", X_test.shape)
print("Training labels:", y_train.shape)
print("Testing labels:", y_test.shape)
# Out:
# ...
# 29515/29515 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# ...
# 26421880/26421880 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# ...
# 5148/5148 ━━━━━━━━━━━━━━━━━━━━ 0s 1us/step
# ...
# 4422102/4422102 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Training images: (60000, 28, 28)
# Testing images: (10000, 28, 28)
# Training labels: (60000,)
# Testing labels: (10000,)

# %% [markdown]
# Sample Images

# %%
plt.figure(figsize=(10, 6))

for i in range(12):
    plt.subplot(3, 4, i + 1)
    plt.imshow(X_train[i], cmap="gray")
    plt.title(class_names[y_train[i]])
    plt.axis("off")

plt.suptitle("Sample Images from Fashion-MNIST", fontsize=14, fontweight="bold")
plt.tight_layout()

plt.savefig("sample_images.png", dpi=300, bbox_inches="tight")
plt.show()

# %%
X_train = X_train.astype("float32") / 255.0
X_test = X_test.astype("float32") / 255.0

X_train = X_train.reshape(-1, 28, 28, 1)
X_test = X_test.reshape(-1, 28, 28, 1)

y_train_cat = to_categorical(y_train, 10)
y_test_cat = to_categorical(y_test, 10)

print("Processed training shape:", X_train.shape)
print("Processed testing shape:", X_test.shape)
# Out:
# Processed training shape: (60000, 28, 28, 1)
# Processed testing shape: (10000, 28, 28, 1)

# %% [markdown]
# CNN Model

# %%
model = Sequential([
    Conv2D(
        filters=32,
        kernel_size=(3, 3),
        activation="relu",
        input_shape=(28, 28, 1),
        name="conv_layer_1"
    ),
    MaxPooling2D(pool_size=(2, 2), name="max_pool_1"),

    Conv2D(
        filters=64,
        kernel_size=(3, 3),
        activation="relu",
        name="conv_layer_2"
    ),
    MaxPooling2D(pool_size=(2, 2), name="max_pool_2"),

    Flatten(),
    Dense(128, activation="relu"),
    Dropout(0.3),
    Dense(10, activation="softmax")
])

model.compile(
    optimizer="adam",
    loss="categorical_crossentropy",
    metrics=["accuracy"]
)

model.summary()
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/convolutional/base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv_layer_1 (Conv2D)           │ (None, 26, 26, 32)     │           320 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pool_1 (MaxPooling2D)       │ (None, 13, 13, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# ...

# %% [markdown]
# Train CNN Model

# %%
history = model.fit(
    X_train,
    y_train_cat,
    epochs=8,
    batch_size=64,
    validation_split=0.2,
    verbose=1
)
# Out:
# Epoch 1/8
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 47s 58ms/step - accuracy: 0.7905 - loss: 0.5795 - val_accuracy: 0.8622 - val_loss: 0.3847
# Epoch 2/8
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 82s 59ms/step - accuracy: 0.8643 - loss: 0.3757 - val_accuracy: 0.8756 - val_loss: 0.3444
# Epoch 3/8
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 43s 57ms/step - accuracy: 0.8815 - loss: 0.3261 - val_accuracy: 0.8908 - val_loss: 0.3012
# Epoch 4/8
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 45s 60ms/step - accuracy: 0.8923 - loss: 0.2936 - val_accuracy: 0.8947 - val_loss: 0.2863
# Epoch 5/8
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 80s 58ms/step - accuracy: 0.9010 - loss: 0.2696 - val_accuracy: 0.8972 - val_loss: 0.2751
# Epoch 6/8
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 44s 59ms/step - accuracy: 0.9087 - loss: 0.2488 - val_accuracy: 0.9012 - val_loss: 0.2698
# Epoch 7/8
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 79s 56ms/step - accuracy: 0.9148 - loss: 0.2289 - val_accuracy: 0.9061 - val_loss: 0.2578
# Epoch 8/8
# ...

# %% [markdown]
# Performance training plots

# %%
plt.figure(figsize=(9, 5))

plt.plot(history.history["accuracy"], marker="o", label="Training Accuracy")
plt.plot(history.history["val_accuracy"], marker="o", label="Validation Accuracy")

plt.title("CNN Training and Validation Accuracy", fontsize=14, fontweight="bold")
plt.xlabel("Epoch")
plt.ylabel("Accuracy")
plt.legend()
plt.grid(alpha=0.3)

plt.tight_layout()
plt.savefig("training_accuracy.png", dpi=300, bbox_inches="tight")
plt.show()

# %%
plt.figure(figsize=(9, 5))

plt.plot(history.history["loss"], marker="o", label="Training Loss")
plt.plot(history.history["val_loss"], marker="o", label="Validation Loss")

plt.title("CNN Training and Validation Loss", fontsize=14, fontweight="bold")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.legend()
plt.grid(alpha=0.3)

plt.tight_layout()
plt.savefig("training_loss.png", dpi=300, bbox_inches="tight")
plt.show()

# %% [markdown]
# Evaluating the model

# %%
test_loss, test_accuracy = model.evaluate(X_test, y_test_cat, verbose=0)

print(f"Test Loss: {test_loss:.4f}")
print(f"Test Accuracy: {test_accuracy:.4f}")
# Out:
# Test Loss: 0.2706
# Test Accuracy: 0.9024

# %%
y_pred_probs = model.predict(X_test)
y_pred = np.argmax(y_pred_probs, axis=1)

print(classification_report(y_test, y_pred, target_names=class_names))
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step
#               precision    recall  f1-score   support
#
#  T-shirt/top       0.88      0.83      0.85      1000
#      Trouser       1.00      0.97      0.98      1000
#     Pullover       0.81      0.89      0.85      1000
#        Dress       0.90      0.92      0.91      1000
#         Coat       0.87      0.82      0.84      1000
#       Sandal       0.98      0.98      0.98      1000
#        Shirt       0.70      0.73      0.71      1000
#      Sneaker       0.94      0.98      0.96      1000
#          Bag       0.99      0.97      0.98      1000
#   Ankle boot       0.99      0.95      0.97      1000
#
#     accuracy                           0.90     10000
#    macro avg       0.90      0.90      0.90     10000
# weighted avg       0.90      0.90      0.90     10000

# %% [markdown]
# Confusion Matrix for CNN

# %%
cm = confusion_matrix(y_test, y_pred)

plt.figure(figsize=(9, 7))

sns.heatmap(
    cm,
    annot=True,
    fmt="d",
    cmap="Blues",
    xticklabels=class_names,
    yticklabels=class_names
)

plt.title("Confusion Matrix for CNN Predictions", fontsize=14, fontweight="bold")
plt.xlabel("Predicted Label")
plt.ylabel("True Label")
plt.xticks(rotation=45, ha="right")
plt.yticks(rotation=0)

plt.tight_layout()
plt.savefig("confusion_matrix.png", dpi=300, bbox_inches="tight")
plt.show()

# %% [markdown]
# Feature Map Visualisation

# %%
image_index = 0

selected_image = X_test[image_index]
selected_label = y_test[image_index]

plt.figure(figsize=(4, 4))
plt.imshow(selected_image.squeeze(), cmap="gray")
plt.title(f"Original Image - {class_names[selected_label]}", fontweight="bold")
plt.axis("off")

plt.tight_layout()
plt.savefig("original_image.png", dpi=300, bbox_inches="tight")
plt.show()

# %%
layer1_model = Model(
    inputs=model.layers[0].input,
    outputs=model.get_layer("conv_layer_1").output
)

layer1_features = layer1_model.predict(selected_image.reshape(1, 28, 28, 1))

print("Layer 1 feature map shape:", layer1_features.shape)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# Layer 1 feature map shape: (1, 26, 26, 32)

# %%
plt.figure(figsize=(10, 8))

for i in range(16):
    plt.subplot(4, 4, i + 1)
    plt.imshow(layer1_features[0, :, :, i], cmap="viridis")
    plt.title(f"Map {i+1}")
    plt.axis("off")

plt.suptitle("Feature Maps from First Convolution Layer", fontsize=14, fontweight="bold")
plt.tight_layout()

plt.savefig("layer1_feature_maps.png", dpi=300, bbox_inches="tight")
plt.show()

# %%
layer2_model = Model(
    inputs=model.layers[0].input,
    outputs=model.get_layer("conv_layer_2").output
)

layer2_features = layer2_model.predict(selected_image.reshape(1, 28, 28, 1))

print("Layer 2 feature map shape:", layer2_features.shape)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# Layer 2 feature map shape: (1, 11, 11, 64)

# %%
plt.figure(figsize=(10, 8))

for i in range(16):
    plt.subplot(4, 4, i + 1)
    plt.imshow(layer2_features[0, :, :, i], cmap="viridis")
    plt.title(f"Map {i+1}")
    plt.axis("off")

plt.suptitle("Feature Maps from Second Convolution Layer", fontsize=14, fontweight="bold")
plt.tight_layout()

plt.savefig("layer2_feature_maps.png", dpi=300, bbox_inches="tight")
plt.show()

# %% [markdown]
# Predicted Correct Image

# %%
correct_indices = np.where(y_pred == y_test)[0]

correct_index = correct_indices[0]

correct_image = X_test[correct_index]
correct_true = y_test[correct_index]
correct_pred = y_pred[correct_index]
correct_confidence = np.max(y_pred_probs[correct_index])

plt.figure(figsize=(4, 4))
plt.imshow(correct_image.squeeze(), cmap="gray")
plt.title(
    f"Correct Prediction\n"
    f"True: {class_names[correct_true]} | Predicted: {class_names[correct_pred]}\n"
    f"Confidence: {correct_confidence:.2%}",
    fontweight="bold"
)
plt.axis("off")

plt.tight_layout()
plt.savefig("correct_prediction.png", dpi=300, bbox_inches="tight")
plt.show()

# %% [markdown]
# Incorrect prediction

# %%
incorrect_indices = np.where(y_pred != y_test)[0]

incorrect_index = incorrect_indices[0]

incorrect_image = X_test[incorrect_index]
incorrect_true = y_test[incorrect_index]
incorrect_pred = y_pred[incorrect_index]
incorrect_confidence = np.max(y_pred_probs[incorrect_index])

plt.figure(figsize=(4, 4))
plt.imshow(incorrect_image.squeeze(), cmap="gray")
plt.title(
    f"Incorrect Prediction\n"
    f"True: {class_names[incorrect_true]} | Predicted: {class_names[incorrect_pred]}\n"
    f"Confidence: {incorrect_confidence:.2%}",
    fontweight="bold"
)
plt.axis("off")

plt.tight_layout()
plt.savefig("incorrect_prediction.png", dpi=300, bbox_inches="tight")
plt.show()
